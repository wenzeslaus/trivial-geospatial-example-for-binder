# %%
# !ls
# Out:
#  LICENSE   README.md   requirements.txt   run.py  'View data.ipynb'

# %%
# !python run.py
# Out:
# EPSG:4269

# %%
import rasterio
dem = rasterio.open("elevation.tif")
array = dem.read(1)
from matplotlib import pyplot
# %matplotlib inline
pyplot.imshow(array, cmap='pink')
pyplot.show()
