# %%
# !ls
# Out:
# LICENSE  README.md  requirements.txt  run.py  Untitled.ipynb

# %%
# !python run.py
# Out:
# EPSG:4269

# %%
import rasterio
dem = rasterio.open("http://fatra.cnr.ncsu.edu/us-iale2017/US_elevation.tif")
array = dem.read(1)
from matplotlib import pyplot
# %matplotlib inline
pyplot.imshow(array, cmap='pink')
pyplot.show()
